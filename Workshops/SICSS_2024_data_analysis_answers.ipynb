# %% [markdown]
# # SICSS-AMU/Law 2024
# ## June 21, 2024 | Adam Mickiewicz University
# ![WhatsApp Image 2024-06-03 at 21.41.49.jpeg](data:image/jpeg;base64,...)
# #### prepared by Jędrzej Wydra
# [LinkedIn](https://www.linkedin.com/in/j%C4%99drzej-wydra-3b12b4232/), [Google Scholar](https://scholar.google.pl/citations?user=arKNI6UAAAAJ&hl=pl&oi=ao)

# %% [markdown]
# # Abstract
#
# **Introduction**: The Polish Criminal Code groups crimes into thematic chapters, such as "crimes against life and health," "crimes against property," and "crimes against national defense." The Polish government does not provide an official English translation of the Criminal Code.
#
# **Hypotheses**:
# 1. The chapters of the Polish Criminal Code vary in their average punitiveness.
# 2. The chapters of the Polish Criminal Code are ordered by the severity of penalties.
#
# **Main Goals**:
# 1. *Data Preparation:* Participants identify potential issues with extracting data from the Polish Criminal Code, upload the Code into the Python environment, clean the data, and analyze its structure from a programming perspective.
# 2. *Data Translation:* Participants translate the Criminal Code into English using Google Translate within the Python environment.
# 3. *Data Analysis:* Participants use statistical methods to test the research hypotheses, checking for significant differences in average punitiveness across chapters and designing a statistical test to determine if the chapters are ordered by the severity of penalties.
#
# **Methods**: Data extraction is performed using standard Python methods, such as loading PDF files and utilizing REGEX. Data cleaning is done using functionalities provided by ChatGPT. The first hypothesis is tested using standard statistical tests like ANOVA, the Kruskal-Wallis test and post hoc tests. The second hypothesis is tested through a procedure designed with participants.
#
# **Outcomes**: Based on the results, participants determine whether to accept or reject the research hypotheses.

# %% [markdown]
# ## The first disclaimer
#
# This workshop is more about analysis and less about programming. So most necessary code is provided to you as functions in SICSS module.
#
# Our goal today is to think, not to write a code.

# %%
# Make sure you have uploaded the necessary files (cc.pdf and sicss_amu_2024.py) to the storage space (files tab).

# %%
# Run this code to install necessary modules

# !pip install PyPDF2
# !pip install openai
# !pip install deep_translator
# !pip install scikit_posthocs

# %%
# Run this code to import necessary modules

import sicss_amu_2024 as sicss
import numpy as np
import scikit_posthocs as sp
import matplotlib.pyplot as plt
import re
from tqdm import tqdm
from deep_translator import GoogleTranslator
from scipy.stats import shapiro, f_oneway, kruskal, tukey_hsd
from scipy.special import comb

# %% [markdown]
# ## The second disclaimer
#
# The SICSS module, which is provided for you, is useful only during this workshop. Its functions are not for general use; they are specifically tailored for the following exercises.
#
# ChatGPT was indeed used for some tasks, but the respective function from the SICSS module just simulates the behavior of ChatGPT and returns exactly the same output as ChatGPT, without using it directly. The main reason for this is to expedite the workflow of this workshop, as the real use of ChatGPT would be unnecessarily time-consuming.
#
# If you want to use ChatGPT in a similar way for your group project next week, please ask me for help and I will do my best.

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise 1.**
#
# Inspect the file 'cc.pdf' and identify potential problems with extracting data. Make a discussion about that.
#
# HINT: You should find two the most obvious by looking at margins and footers.

# %% [markdown]
# **Exercise 2.**
#
# Upload the file 'cc.pdf' to Python's local environment using our pre-defined function from our SICSS module.

# %%
# Use the function upload_criminal_code(path) from our SICSS module.

criminal_code = sicss.upload_criminal_code('cc.pdf')

## HINT: to use a function from a given module, you should follow the pattern:
## module_name.function_name(arguments)
## which means that a name of a module should and a name of a function should be separate by a dot.
# Out:
# 100%|██████████| 146/146 [00:09<00:00, 14.85it/s]

# %% [markdown]
# **Exercise 3.**
#
# Examine the structure of the uploaded file, then save 'general_part' and 'special_part' in separate variables. Make a discussion about that.

# %%
# Use the function type(). What does the output mean?

## HINT: a function is used before arguments, pattern:
## function_name(arguments)

## HINT2: you uploaded file should be stored in the variable criminal_code.

type(criminal_code)
# Out:
# dict

# %%
# Use the method .keys() of a dict. What did you get?

## HINT: a method is used after its object, a dot separates object's name and method's name,
## at the end you always have brackets, pattern:
## object.method_name()

criminal_code.keys()
# Out:
# dict_keys(['general_part', 'special_part', 'military_part'])

# %%
# Take a look at these values of above keys.

## HINT: to get access to a value of given key, you should put the key between quote signs
## and square brackets after object's name, pattern:
## object['key']

criminal_code['general_part']
# Out:
# '####Rozdział I Zasady odpowiedzialności karnej ###Art. 1. ##§ 1. Odpowiedzialności karnej podlega ten tylko, kto popełnia czyn zabroniony pod groźbą kary przez ustawę obowiązującą w czasie jego popełnienia. ##§ 2. Nie stanowi przestępstwa czyn zabroniony, którego społeczna szkodliwość jest znikoma. ##§ 3. Nie popełnia przestępstwa sprawca czynu zabronionego, jeżeli nie można mu przypisać winy w czasie czynu. ###Art. 2. ##Odpowiedzialności karnej za przestępstwo skutkowe popełnione przez zaniechanie podlega ten tylko, na kim ciążył prawny, szczególny obowiąz ek zapobiegnięcia skutkowi. ###Art. 3. ##Kary oraz inne środki przewidziane w tym kodeksie stosuje się z uwzględnieniem zasad humanitaryzmu, w szczególności z poszanowaniem godności człowieka. ###Art. 4. ##§ 1. Jeżeli w czasie orzekania obowiązuje ustawa inna niż w czasie popełnienia przestępstwa, stosuje się ustawę nową, jednakże należy stosować ustawę obowiązującą poprzednio, jeżeli jest względniejsza dla sprawcy. ##§ 2. Jeżeli według nowej ustawy za czyn objęty wyrokiem nie można orzec kary w wysokości kary orzeczon ej, wymierzoną karę obniża się do wysokości najsurowszej kary możliwej do orzeczenia na podstawie nowej ustawy. ##§ 3. Jeżeli według nowej ustawy czyn objęty wyrokiem nie jest już zagrożony karą pozbawienia wolności, wymierzoną karę pozbawienia wolności podl egającą wykonaniu zamienia się na grzywnę albo karę ograniczenia wolności, przyjmując że jeden miesiąc pozbawienia wolności równa się 60 stawkom dziennym grzywny albo 2 miesiącom ograniczenia wolności. ##§ 4. Jeżeli według nowej ustawy czyn objęty wyrokiem n ie jest już zabroniony pod groźbą kary, skazanie ulega zatarciu z mocy prawa. ###Art. 5. ##Ustawę karną polską stosuje się do sprawcy, który popełnił czyn zabroniony na terytorium Rzeczypospolitej Polskiej, jak również na polskim statku wodnym lub powietrznym, chyba że umowa międzynarodowa, której Rzeczpospolita Polska jest stroną, stanowi inaczej. ###Art. 6. ##§ 1. Czyn zabroniony uważa się za popełniony w czasie, w którym sprawca działał lub zaniechał działania, do którego był obowiązany. ##§ 2. Czyn zabroniony uważa się za popełniony w miejscu, w którym sprawca działał lub zaniechał działania, do którego był obowiązany, albo gdzie skutek stanowiący znamię czynu zabronionego nastąpił lub według zamiaru sprawcy miał nastąpić. ###Art. 7. ##§ 1. Przestępstwo jest zbrodnią alb o występkiem. ##§ 2. Zbrodnią jest czyn zabroniony zagrożony karą pozbawienia wolności na czas nie krótszy od lat 3 albo karą surowszą. ##§ 3. Występkiem jest czyn zabroniony zagrożony grzywną powyżej 30 stawek dziennych albo powyżej 5000 złotych, karą ogranic zenia wolności przekraczającą miesiąc albo karą pozbawienia wolności przekraczającą miesiąc. ###Art. 8. ##Zbrodnię można popełnić tylko umyślnie; występek można popełnić także nieumyślnie, jeżeli ustawa tak stanowi. ###Art. 9. ##§ 1. Czyn zabroniony popełniony jest umyślnie, jeżeli sprawca ma zamiar jego popełnienia, to jest chce go popełnić albo przewidując możliwość jego popełnienia, na to się godzi. ##§ 2. Czyn zabroniony popełniony jest nieumyślnie, jeżeli sprawca nie mając zamiaru jego popełnienia, popełnia go jed nak na skutek niezachowania ostrożności wymaganej w danych okolicznościach, mimo że możliwość popełnienia tego czynu przewidywał albo mógł przewidzieć. ##§ 3. Sprawca ponosi surowszą odpowiedzialność, którą ustawa uzależnia od określonego następstwa czynu za bronionego, jeżeli następstwo to przewidywał albo mógł przewidzieć. ###Art. 10. ##§ 1. Na zasadach określonych w tym kodeksie odpowiada ten, kto popełnia czyn zabroniony po ukończeniu 17 lat. ##§ 2. Nieletni, który po ukończeniu 15 lat dopuszcza się czynu zabroni onego określonego w art. 134, art. 148 § 1, 2 lub 3, art. 156 § 1 lub 3, art. 163 § 1 lub 3, art. 166, art. 173 § 1 lub 3, art. 197 § 1, 3, 4 lub 5, art. 223 § 2, art. 252 § 1 lub 2 oraz w art. 280, może odpowiadać na zasadach określonych w tym kodeksie, j eżeli okoliczności sprawy oraz stopień r ...

# %%
# @title Additional exercise, come back here after completing whole colab
# We use the method .split() of a string to change a string into list.
# In the string below there are special characters: #### next to Chapter, ### next to Article, ## next to paragraph.
# This special characters should help in spliting this string into list.
# Why they are sequences of '#'?
# Would it work in different order?
# E.g. ## next to Chapter, ### next to Article, #### next to paragraph.
# Could you use different characters than '#' to obtain the same result?
sicss.sicss_eng_hashtags['eng']
# Out:
# '####Chapter I Rules of criminal liability ###Art. 1. ##§ 1. Only those who commit an act prohibited under penalty by the law in force at the time of its commission are subject to criminal liability. ##§ 2. A prohibited act whose social harmfulness is negligible does not constitute a crime. ##§ 3. The perpetrator of a prohibited act does not commit a crime if no guilt can be attributed to him at the time of the act. ###Art. 2. ##Only those who had a legal, specific obligation to prevent the consequence are subject to criminal liability for a consequential crime committed by omission. ###Art. 3. ##Penalties and other measures provided for in this Code shall be applied taking into account the principles of humanitarianism, in particular respect for human dignity. ###Art. 4. ##§ 1. If, at the time of adjudication, a different law is in force than at the time of committing the crime, the new law shall apply, however, the previously applicable law shall apply if it is more favorable to the perpetrator. ##§ 2. If, under the new Act, a penalty in the amount of the imposed penalty cannot be imposed for the act covered by the judgment, the penalty imposed shall be reduced to the amount of the most severe penalty possible to be imposed under the new Act. ##Remove unnecessary spaces from § 3. If, according to the new Act, the act covered by the judgment is no longer punishable by imprisonment, the imposed enforceable penalty of imprisonment is replaced by a fine or restriction of liberty, assuming that one month of imprisonment is equal to 60 daily fines or 2 months of restriction of liberty. ##§ 4. If, according to the new law, the act covered by the judgment is no longer prohibited under penalty, the conviction is expunged by operation of law. ###Art. 5. ##The Polish criminal law shall apply to a perpetrator who has committed a prohibited act on the territory of the Republic of Poland, as well as on a Polish ship or aircraft, unless an international agreement to which the Republic of Poland is a party provides otherwise. ###Art. 6. ##§ 1. A prohibited act is deemed to have been committed at the time when the perpetrator acted or refrained from acting to which he was obliged. ##§ 2. A prohibited act is deemed to have been committed in the place where the perpetrator acted or omitted to act to which he was obliged, or where the effect constituting the hallmark of the prohibited act occurred or was to occur according to the perpetrator\'s intention. ###Art. 7. ##§ 1. An offense is a crime or a misdemeanor. ##§ 2. A crime is a prohibited act punishable by imprisonment for a period of not less than 3 years or a more severe penalty. ##§ 3. A misdemeanor is a prohibited act punishable by a fine exceeding 30 daily rates or more than PLN 5,000, a penalty of restriction of liberty exceeding one month or a penalty of deprivation of liberty exceeding one month. ###Art. 8. ##A crime can only be committed intentionally; an offense may also be committed unintentionally if the law so provides. ###Art. 9. ##§ 1. A prohibited act is committed intentionally if the perpetrator has the intention to commit it, that is, wants to commit it or, anticipating the possibility of committing it, agrees to it. ##§ 2. A prohibited act is committed unintentionally if the perpetrator, having no intention of committing it, commits it as a result of failure to exercise the caution required in the given circumstances, even though the possibility of committing the act was or could have been foreseen. ##§ 3. The perpetrator bears more severe liability, which the law makes dependent on the specific consequences of the defended act, if he anticipated or could have foreseen this consequence. ###Art. 10. ##§ 1. Anyone who commits a prohibited act after reaching the age of 17 is liable under the principles set out in this Code. ##§ 2. A minor who, after reaching the age of 15, commits a prohibited act specified in Art. 134, art. 148 § 1, 2 or 3, art. 156 § 1 or 3, art. 163 § 1 o ...

# %%
# Use the function type() for value of each key. What does the output mean?

## HINT: the value of the key in a given object is another object.
## object['key'] is different object than just object.

type(criminal_code['general_part'])
# Out:
# str

# %%
# Use the function len() for value of each key. What does the output mean?

## HINT: this is analogical to use of type() in exercise 3.

len(criminal_code['general_part'])
# Out:
# 114320

# %%
# Assign the value of general_part to variable 'general_part_string'.

general_part_string = criminal_code['general_part']

# Assign the value of special_part to variable 'special_part_string'.

special_part_string = criminal_code['special_part']

## HINT: remember that general_part and special_part are the keys of the criminal_code.

# %% [markdown]
# **Exercise 4.**
#
# Examine a structure of the variables from previous exercise. Make a discussion about that.

# %%
# Use the function type(). What does the output mean?

## HINT: you should do the same as in the previous exercise,
## but now with object general_part_string and special_part_string.

## HINT2: you should do it twice, after the first time delete the code and write another one.

type(general_part_string)
# Out:
# str

# %%
# Use the function len(). What does the output mean?

## HINT: you should do the same as in the previous exercise,
## but now with different objects

## HINT2: you should do it twice, after the first time delete the code and write another one.

len(general_part_string)
# Out:
# 114320

# %% [markdown]
# **Exercise 5.**
#
# Convert strings from previous exercise to dictionary using our pre-defined function from our SICSS module. Discuss why dictrionary is better to strore Criminal Code.

# %%
# Use the function convert_string_to_dict(string) from our SICSS module.
# What should be a key? What should be a value?

kk_general = sicss.convert_string_to_dict(general_part_string)
kk_special = sicss.convert_string_to_dict(special_part_string)

## HINT: this is analogical to the exercise 2.

# %% [markdown]
# **Exercise 6.**
#
# Examine the structure of obtained variables. Get access to the article 147, which is in the chapter 'Rozdział XVIII Przestępstwa przeciwko obronności'. Look carefully if everything is ok. Identify a problem. Make a discussion about that.
#
# HINT: in polish there is no such conotation as 'prz estępstwa', in polish there is a single word 'przestępstwa'.

# %%
# Use the function type(). What does the output mean?

## HINT: you used type() in the previous exercises.

type(kk_special)
# Out:
# dict

# %%
# Use the method .keys() of dict.

## HINT: you used .keys() in the previous exercises.

kk_special.keys()
# Out:
# dict_keys(['Rozdział XVI Przestępstwa przeciwko pokojowi, ludzkości oraz przestępstwa wojenne ', 'Rozdział XVII Przestępstwa przeciwko Rzeczypospolitej Polskiej ', 'Rozdział XVIII Przestępstwa przeciwko obronności ', 'Rozdział XIX Przestępstwa przeciwko życiu i zdrowiu ', 'Rozdział XX Przestępstwa przeciwko bezpieczeństwu powszechnemu ', 'Rozdział XXI Przestępstwa przeciwko bezpieczeństwu w komunikacji ', 'Rozdział XXII Przestępstwa przeciwko środowisku ', 'Rozdział XXIII Przestępstwa przeciwko wolności ', 'Rozdział XXIV Przestępstwa przeciwko wolności sumienia i wyznania ', 'Rozdział XXV Przestępstwa przeciwko wolności seksualnej i obyczajności ', 'Rozdział XXVI Przestępstwa przeciwko rodzinie i opiece ', 'Rozdział XXVII Przestępstwa przeciwko czci i nietykalności cielesnej ', 'Rozdział XXVIII Przestępstwa przeciwko prawom osób wykonujących pracę zarobkową ', 'Rozdział XXIX Przestępstwa przeciwko działalności instytucji państwowych oraz samorządu terytorialnego ', 'Rozdział XXX Przestępstwa przeciwko wymiarowi sprawiedliwości ', 'Rozdział XXXI Przestępstwa przeciwko wyborom i referendum ', 'Rozdział XXXII Przestępstwa przeciwko porządkowi publicznemu ', 'Rozdział XXXIII Przestępstwa przeciwko ochronie informacji ', 'Rozdział XXXIV Przestępstwa przeciwko wiarygodności dokumentów ', 'Rozdział XXXV Przestępstwa przeciwko mieniu ', 'Rozdział XXXVI Przestępstwa przeciwko obrotowi gospodarczemu i interesom majątkowym w obrocie cywilnoprawnym ', 'Rozdział XXXVII Przestępstwa przeciwko obrotowi pieniędzmi i papierami wartościowymi '])

# %%
# Get access to the value of key 'Rozdział XVIII Przestępstwa przeciwko obronności '
# Be carefull and notice that at the end of the key is white space.
# Can you get access to value without this whitespace?

kk_special['Rozdział XVIII Przestępstwa przeciwko obronności ']
# Out:
# {'Art. 140. ': ['§ 1. Kto, w celu osłabienia mocy obronnej Rzeczypospolitej Polskiej, dopuszcza się gwałtownego zamachu na jednostkę Sił Zbrojnych Rzeczypospolitej Polskiej, niszczy lub uszkadza obiekt albo urządzenie o znaczeniu obronnym, podlega karze pozbawienia wolności od roku do lat 10. ',
#   '§ 2. Jeżeli następst wem czynu jest śmierć człowieka lub ciężki uszczerbek na zdrowiu wielu osób, sprawca podlega karze pozbawienia wolności od lat 2 do 15. ',
#   '§ 3. Kto czyni przygotowania do przestępstwa określonego w § 1, podlega karze pozbawienia wolności do lat 3. ',
#   '§ 4. W sprawie o przestępstwo określone w § 1–3 sąd może orzec przepadek przedmiotów również wtedy, gdy przedmioty nie stanowią własności sprawcy. '],
#  'Art. 141. ': ['§ 1. Kto, będąc obywatelem polskim, przyjmuje bez zgody właściwego organu obowiązki wojskowe w obcym wojsku lu b w obcej organizacji wojskowej, podlega karze pozbawienia wolności od 3 miesięcy do lat 5. ',
#   '§ 2. Kto przyjmuje obowiązki w zakazanej przez prawo międzynarodowe wojskowej służbie najemnej, podlega karze pozbawienia wolności od 6 miesięcy do lat 8. ',
#   '§ 3. Nie popełnia przestępstwa określonego w § 1 obywatel polski będący równocześnie obywatelem innego państwa, jeżeli zamieszkuje na jego terytorium i pełni tam służbę wojskową. '],
#  'Art. 142. ': ['§ 1. Kto, wbrew przepisom ustawy, prowadzi zaciąg obywateli polskich lub prz ebywających w Rzeczy pospolitej Polskiej cudzoziemców do służby wojskowej w obcym wojsku lub w obcej organizacji wojskowej, podlega karze pozbawienia wolności od 3 miesięcy do lat 5. ',
#   '§ 2. Kto prowadzi zaciąg obywateli polskich lub przebywających w Rzeczyp ospolitej Polskiej cudzoziemców do służby w zakazanej przez prawo międzynarodowe wojskowej służbie najemnej albo taką służbę najemną opłaca, organizuje, szkoli lub wykorzystuje, podlega karze pozbawienia wolności od 6 miesięcy do lat 8. '],
#  'Art. 143. ': ['§ 1. Kto, w celu uzyskania zwolnienia od obowiązku służby wojskowej albo odroczenia tej służby, powoduje u siebie lub dopuszcza, by kto inny spowodował u niego skutek określony w art. 156 § 1 lub art. 157 § 1 albo w tym celu używa podstępu dla wprowadzenia w błąd w łaściwego organu, podlega karze pozbawienia wolności do lat 3. ',
#   '§ 2. Tej samej karze podlega, kto, w celu ułatwienia innej osobie zwolnienia od obowiązku służby wojskowej albo odroczenia tej służby, za jej zgodą powoduje u niej skutek określony w art. 156 § 1 lub art. 157 § 1 albo w tym celu używa podstępu dla wprowadzenia w błąd właściwego organu. ',
#   '§ 3. Kto dopuszcza się czynu zabronionego określonego w § 1 lub 2, jeżeli obowiązek dotyczy służby zastępującej służbę wojskową, podlega grzywnie, karze ogranicze nia wolności albo pozbawienia wolności do lat 2. '],
#  'Art. 144. ': ['§ 1. Kto, będąc powołanym do pełnienia czynnej służby wojskowej, nie zgłasza się do odbywania tej służby w określonym terminie i miejscu, podlega karze pozbawienia wolności do lat 3. ',
#   '§ 2. W wypadku mniejszej wagi, sprawca podlega grzywnie, karze ograniczenia wolności albo pozbawienia wolności do roku. ',
#   '§ 3. Kto nie zgłasza się do odbywania służby zastępującej służbę wojskową w warunkach określonych w § 1, podlega grzywnie albo karze ograniczenia woln ości. '],
#  'Art. 145. ': ['§ 1. Kto, odbywając służbę zastępującą służbę wojskową: #1) odmawia pełnienia tej służby, złośliwie lub uporczywie odmawia wykonania obowiązku wynikającego z tej służby albo polecenia w sprawach służbowych, #2) w celu częściowego lub zupełneg o uchylenia się od tej służby albo wykonania obowiązku wynikającego z tej służby: a) powoduje u siebie lub dopuszcza, by kto inny spowodował u niego skutek określony w art. 156 § 1 lub art. 157 § 1, b) używa podstępu dla wprowadzenia w błąd przełożonego, podlega grzywnie, karze ograniczenia wolności albo pozbawienia wolności do lat 2. ',
#   '§ 2. Tej samej karze podlega, kto, pełniąc służbę określoną w § 1, samowolnie opuszcza wyznaczone miejsce wykonywania obowiązków służbowych lub samowolnie poza nim pozostaje. ',
#   '§ 3. Jeżeli sprawca czynu zabronionego określonego w § 2 opuszcza, w celu trwałego uchylenia się od tej służby, wyznaczone miejsce wykonywania obowiązków służbowych albo w takim celu poza nimi pozostaje, podlega karze pozbawienia wolności do lat 3. '],
#  'Art. 146. ': ['Jeżeli sprawca przestępstwa określonego w art. 145 § 2 i 3 dobrowolnie powrócił, a jego nieobecność trwała nie dłużej niż 14 dni, sąd może zastosować nadzwyczajne złagodzenie kary, a nawet odstąpić od jej wymierzenia. '],
#  'Art. 147. ': ['W stosunku do sprawcy prz estępstwa określonego w art. 143 § 1 lub w art. 144 lub 145, który w chwili czynu był niezdolny do pełnienia służby wojskowej, sąd może zastosować nadzwyczajne złagodzenie kary, a nawet odstąpić od jej wymierzenia. ']}

# %%
# Use the function type() on the object you displayed in the previous cell.
# What does the output mean?

type(kk_special['Rozdział XVIII Przestępstwa przeciwko obronności '])
# Out:
# dict

# %%
# Use the method .keys() of dict in the same object as in the previous cell.

kk_special['Rozdział XVIII Przestępstwa przeciwko obronności '].keys()
# Out:
# dict_keys(['Art. 140. ', 'Art. 141. ', 'Art. 142. ', 'Art. 143. ', 'Art. 144. ', 'Art. 145. ', 'Art. 146. ', 'Art. 147. '])

# %%
# Get access to the value of the key 'Art. 147. '
# of the value of the key 'Rozdział XVIII Przestępstwa przeciwko obronności '.
# Be carefull.


## HINT: dictionary['key1']['key2']
## If the above does not work it might mean that you put keys in incorrect order.

kk_special['Rozdział XVIII Przestępstwa przeciwko obronności ']['Art. 147. ']
# Out:
# ['W stosunku do sprawcy prz estępstwa określonego w art. 143 § 1 lub w art. 144 lub 145, który w chwili czynu był niezdolny do pełnienia służby wojskowej, sąd może zastosować nadzwyczajne złagodzenie kary, a nawet odstąpić od jej wymierzenia. ']

# %%
# Run this cell.
# How does the above output differ from below one?

kk_special['Rozdział XVIII Przestępstwa przeciwko obronności ']['Art. 147. '][0]

# HINT: you can use function type() in another cell.
# Out:
# 'W stosunku do sprawcy prz estępstwa określonego w art. 143 § 1 lub w art. 144 lub 145, który w chwili czynu był niezdolny do pełnienia służby wojskowej, sąd może zastosować nadzwyczajne złagodzenie kary, a nawet odstąpić od jej wymierzenia. '

# %% [markdown]
# **Exercise 7.**
#
# Use our pre-defined function from our SICSS module to correct data with a help of ChatGPT.

# %%
# Use the function correction_by_gpt(data_dict) from our SICSS module.

kk_corrected = sicss.correction_by_gpt(kk_special)

## HINT: this is analogical to the exercise 2.
# Out:
# 100%|██████████| 22/22 [00:44<00:00,  2.00s/it]

# %% [markdown]
# **Exercise 8.**
#
# Translate data from polish to english and answer the questions in comments.

# %%
# Why do we need three 'for' loops?

# Why do we need to initialize a new empty dictionary?
cc_special = {}
keys = kk_corrected.keys()
for i in tqdm(keys):
  keys2 = kk_corrected[i].keys()

  # Why do we need to translate text and chapters separetly?
  ii = GoogleTranslator(source='polish', target='english').translate(i) # replace '_________' with your code to translate chapters' titles

  # Why do we need to initialize a new empty dictionary again?
  # Do we do this once?
  cc_special[ii] = {}
  for j in keys2:
    cc_special[ii][j] = []
    for k in range(len(kk_corrected[i][j])):
      list_element = GoogleTranslator(source='polish', target='english').translate(kk_corrected[i][j][k]) # replace '_________' with your code to translate text of criminal code
      cc_special[ii][j].append(list_element)

## HINT: the keys are stored in variable i in every run of a loop.
## HINT2: the text or criminal code is stored in kk_corrected[i][j][k]. Explain why.
# Out:
# 100%|██████████| 22/22 [10:59<00:00, 29.98s/it]

# %%
# Examine 'Chapter XXI Crimes against communication security'

# Why do we need two 'for' loops?

# Why do we iterate over keys here?
for i in cc_special['Chapter XXI Crimes against communication security'].keys():

  # And here over range?
  for j in range(len(cc_special['Chapter XXI Crimes against communication security'][i])):

    # Why do we print variable i here?
    print(i)
    print(cc_special['Chapter XXI Crimes against communication security'][i][j])

## HINT: just run this cell and analyze the output.
# Out:
# Art. 173.
# § 1. Whoever causes a disaster in land, water or air traffic that threatens the life or health of many people or large-scale property, shall be subject to the penalty of imprisonment from one to 10 years.
# Art. 173.
# § 2. If the perpetrator acts unintentionally, he or she shall be subject to the penalty of imprisonment from 3 months to 5 years.
# Art. 173.
# § 3. If the act specified in § 1 results in the death of a person or serious damage to the health of many people, the perpetrator shall be subject to the penalty of imprisonment from 2 to 15 years.
# Art. 173.
# § 4. If the act specified in § 2 results in the death of a person or serious damage to the health of many people, the perpetrator shall be subject to the penalty of imprisonment from 6 months to 8 years.
# Art. 174.
# § 1. Whoever causes an immediate danger of a disaster in land, water or air traffic shall be subject to the penalty of imprisonment from 6 months to 8 years.
# Art. 174.
# § 2. If the perpetrator acts unintentionally, he or she shall be subject to the penalty of imprisonment for up to 3 years.
# Art. 175.
# Who makes preparations for the crime specified in Art. 173 § 1, shall be punishable by imprisonment for up to 3 years.
# Art. 176.
# § 1. The perpetrator of the crime specified in Art. shall not be punished. 174, who voluntarily averted the impending danger.
# Art. 176.
# § 2. With regard to the perpetrator of the offence specified in Article 173 § 1 or 2, the court may apply extraordinary mitigation of punishment if the perpetrator voluntarily averted the danger threatening the life or health of many people.
# Art. 177.
# § 1. Whoever, violating, even unintentionally, the rules of safety in land, water or air traffic, unintentionally causes an accident in which another person suffered bodily injuries specified in Art. 157 § 1, is punishable by imprisonment for up to 3 years.
# Art. 177.
# § 2. If the accident results in the death of another person or serious damage to his or her health, the perpetrator shall be subject to the penalty of imprisonment from 6 months to 8 years.
# Art. 177.
# § 3. If the injured party is only the next of kin, prosecution of the crime specified in § 1 shall take place at the person's request.
# Art. 178.
# Remove unnecessary spaces from § 1. When sentencing a perpetrator who has committed an offense specified in Art. 173 § 1 or 2, art. 174 or art. 177 § 1, being in a state of intoxication or under the influence of a narcotic drug, or fled the scene of the incident, or consumed alcohol or took a narcotic drug after committing the act specified in Art. 173 § 1 or 2, art. 174 or art. 177 § 1, and before being subjected to testing by an authorized body to determine the alcohol content or the presence of a narcotic drug in the body, the court shall impose a penalty of imprisonment for the offense assigned to the perpetrator in the amount from the lower limit of the statutory risk increased by half to the upper limit of this increased risk. by half.
# Art. 178.
# Remove unnecessary spaces from § 1a. When sentencing a perpetrator who has committed an offense specified in Art. 173 § 3 or 4 or art. 177 § 2, in the conditions specified in § 1 or to which the circumstances indicated in this provision apply, the court shall impose a penalty of imprisonment in the amount of: #1) not less than 3 years, if the accident results in serious damage to the health of another person or the catastrophe results serious damage to the health of many people, up to twice the upper limit of the statutory threat, #2) not less than 5 years if the act results in the death of a person, up to twice the upper limit of the statutory threat in the case of a disaster, and 20 years' imprisonment in the case of an accident.
# Art. 178.
# Remove unnecessary spaces from § 2. (repealed) § 3. In the event of a conviction referred to in § 1 or 1a, the court may order forfeiture referred to in Art. 44b, and is imposed if the alcohol content in the perpetrator's body was higher than 1 per mille in the blood or 0.5 mg/dm3 in the exhaled air or led to such a concentration.
# Art. 178a.
# § 1. Whoever, while in a state of intoxication or under the influence of a narcotic drug, drives a motor vehicle in land, water or air traffic shall be subject to the penalty of imprisonment for up to 3 years.
# Art. 178a.
# § 2. (repealed)
# Art. 178a.
# § 3. (repealed)
# Art. 178a.
# Remove unnecessary spaces from § 4. If the perpetrator of the act specified in § 1 was previously legally convicted of driving a motor vehicle under the influence of alcohol or under the influence of a narcotic drug or for an offense specified in Art. 173, art. 174, art. 177 or art. 355 § 2 committed in a state of intoxication or under the influence of a narcotic drug or committed an act specified in § 1 during the period of driving ban imposed in connection with a conviction for an offense, shall be subject to the penalty of imprisonment from 3 months to 5 years. § 5. Court decides on the forfeiture referred to in Art. 44b, in the event of committing the crime specified in § 1 or 4, unless the alcohol content in the body of the perpetrator of the crime specified in § 1 was lower than 1.5 per mille in the blood or 0.75 mg/dm3 in the exhaled air or did not lead to such a concentration . The court may refrain from ordering forfeiture if there is an exceptional case justified by special circumstances.
# Art. 178b.
# The above-mentioned message states that a person who does not stop the vehicle after receiving an order to do so will be subject to the penalty of imprisonment from 3 months to 5 years. Additional paragraphs added to Articles 178 and 178a will enter into force on March 14, 2024. (Journal of Laws of 2022, item 2600 and of 2023, items 403, 1834 and 1860).
# Art. 179.
# Ktowbrewszczególnemuobowiązkowidopuszczadoruchupojazdmechanicznyalboinny pojazd wstaniebezpośredniozagrażającymbzpieczeństwuruchulądowym,wodnym lubpowietrznymlubdopuszczadorowadzeniapojazdumechanicznegoalboinnegopojazdunadrogee publiczną,wstrefiezamieszkanialubwstrefieruchuprzezosobęznajdującą sięwstanienie trzeźwości,będącąpodwpływemśrodkaodurzającegolubosobęnieposiadającąwymaganych uprawnień,podlegagrzywnie,karzeograniczeniawolnościalbopozbawiemiawolności dorelat2.
# Art. 180.
# Whoever, being in a state of intoxication or under the influence of a narcotic substance, performs activities directly related to ensuring the safety of motor vehicle traffic, shall be subject to the penalty of deprivation of liberty for a term of between 3 months and 5 years.
# Art. 180a.
# Whoever drives a motor vehicle on a public road, in a residential zone or in a traffic zone, without complying with the decision of the competent authority to withdraw the driving license, shall be subject to a fine, restriction of liberty or imprisonment for up to 2 years.

# %% [markdown]
# **Exercise 9.**
#
# Run the code below and read the results. Next, examine the special part of polish criminal code (english version) and try to find a patterns how it describes limits of deprivation of liberty. You should find at least 12 patterns.

# %% [markdown]
# HINT:
#
# One of the patterns is 'not less than {digits} years'.
#
# Another pattern is 'from {digits} months to {digits} years'.

# %%
text = sicss.convert_string_to_dict(general_part_string, split_bullets = True)['Rozdział IV Kary ']['Art. 32. '][0]
text2 = sicss.convert_string_to_dict(general_part_string, split_bullets = True)['Rozdział IV Kary ']['Art. 37. '][0]
text2 = re.sub(pattern = '; ', repl = ';\n', string = text2)
print('Art. 32.')
print(GoogleTranslator(source='polish', target='english').translate(text))
print('\nArt. 37.')
print(GoogleTranslator(source='polish', target='english').translate(text2))
# Out:
# Art. 32.
# The penalties are:
# 1) fine;
# 2) restriction of freedom;
# 3) deprivation of liberty;
# 4) (repealed)
# 5) life imprisonment.
#
# Art. 37.
# The penalty of imprisonment specified in Art. 32 point 3 lasts the shortest one month and the longest 30 years;
# it is measured in months and years.

# %%
number_of_chapter = 16 # Asign the number of a chapter (integer from 16 to 37) and run the cell to display it.

chapters = list(cc_special.keys())
for i in cc_special[chapters[number_of_chapter - 16]].keys():
  for j in range(len(cc_special[chapters[number_of_chapter - 16]][i])):
    print(i)
    print(cc_special[chapters[number_of_chapter - 16]][i][j])
# Out:
# Art. 117.
# § 1. Whoever initiates or wages a war of aggression shall be subject to the penalty of deprivation of liberty for a minimum term of 12 years or the penalty of deprivation of liberty for life.
# Art. 117.
# Remove unnecessary spaces from § 2. (repealed)
# Art. 117.
# § 3. Whoever publicly calls for the initiation of a war of aggression or publicly approves the initiation or conduct of such a war shall be subject to the penalty of imprisonment from 3 months to 5 years.
# Art. 118.
# § 1. Whoever, in order to destroy, in whole or in part, a national, ethnic, racial, political, religious group or a group with a specific worldview, commits murder or causes serious damage to the health of a person belonging to such a group, shall be subject to the penalty of deprivation of liberty for a period of time. not less than 12 years or life imprisonment.
# Art. 118.
# § 2. Whoever, for the purposes specified in § 1, creates living conditions for persons belonging to such a group that threaten their biological destruction, applies measures intended to stop births within the group or forcibly takes away children from persons belonging to it, shall be subject to the penalty of deprivation of liberty for years 5 to 25.
# Art. 118.
# Remove unnecessary spaces from § 3. (repealed)
# Art. 118a.
# § 1. Whoever, taking part in a mass attack or even in one of the repeated attacks directed against a group of people undertaken in order to implement or support the policy of the state or organization: #1) commits murder, #2) causes serious damage to human health, #3) creates for persons belonging to a population group living conditions that threaten their biological existence, in particular by depriving them of access to food or medical care, which are intended to destroy them, shall be punishable by imprisonment for a period of not less than 12 years or by life imprisonment freedom.
# Art. 118a.
# § 2. Whoever, taking part in a mass attack or even in one of the repeated attacks directed against a group of people undertaken in order to implement or support the policy of the state or organization: #1) causes a person to be placed in a state of slavery or maintains him in this state, # 2) deprives a person of liberty for a period exceeding 7 days or with particular torment, #3) uses torture or subjects a person to cruel or inhuman treatment, 4) commits rape or violates a person's sexual freedom by using violence, unlawful threats or deceit in any other way, #5) causes a woman to become pregnant by using violence or an unlawful threat with the intention of influencing the ethnic composition of a population group or committing other serious violations of international law, #6) deprives a person of liberty and refuses to provide information regarding this person or his place of residence or provides false information information regarding this person or his place of residence, with the intention of depriving such person of legal protection for a longer period, shall be punishable by imprisonment for a term of 5 to 25 years.
# Art. 118a.
# § 3. Whoever, taking part in a mass attack or even in one of the repeated attacks directed against a group of people undertaken in order to implement or support the policy of a state or organization: #1) in violation of international law forces persons to change their lawful place of residence, #2) commits serious persecution of a group of people for reasons considered unacceptable under international law, in particular political, racial, national, ethnic, cultural, religious or on grounds of non-denomination, belief or gender, resulting in deprivation of fundamental rights, shall be punishable by imprisonment from 3 to 20 years old.
# Art. 119.
# § 1. Whoever uses violence or unlawful threats against a group of people or an individual person because of his or her national, ethnic, racial, political or religious affiliation or because of his or her lack of any religious denomination, shall be subject to the penalty of deprivation of liberty for a term of between 3 months and 5 years.
# Art. 119.
# Remove unnecessary spaces from § 2. (repealed)
# Art. 120.
# Whoever uses a means of mass destruction prohibited by international law shall be subject to the penalty of deprivation of liberty for a minimum term of 10 years or the penalty of deprivation of liberty for life.
# Art. 121.
# § 1. Whoever, contrary to the prohibitions of international law or the provisions of the Act, produces, collects, acquires, sells, stores, transports or sends means of mass destruction or means of warfare, or conducts research aimed at the production or use of such means, shall be subject to the penalty of imprisonment for a term of one year. up to 10 years old
# Art. 121.
# § 2. Whoever allows the act specified in § 1 to be committed shall be subject to the same penalty.
# Art. 122.
# § 1. Whoever, during hostilities, attacks an undefended town or facility, a sanitary, demilitarized or neutralized zone, or uses another method of warfare prohibited by international law, shall be subject to the penalty of imprisonment for a term of 5 to 25 years.
# Art. 122.
# § 2. Anyone who, during hostilities, uses a means of warfare prohibited by international law shall be subject to the same penalty.
# Art. 123.
# § 1. Whoever, in violation of international law, commits murder against: #1) persons who have surrendered by laying down their arms or having no means of defense, #2) the wounded, sick, shipwrecked, medical personnel or clergy, #3) prisoners of war ,#4) the civilian population of an occupied or occupied area or in which hostilities are taking place, or other persons benefiting from international protection during hostilities, shall be subject to the penalty of deprivation of liberty for a period of not less than 12 years or life imprisonment.
# Art. 123.
# § 2. Whoever, in violation of international law, causes serious damage to the health of persons mentioned in § 1, subjects these persons to torture, cruel or inhuman treatment, performs cognitive experiments on them, even with their consent, or uses them to protect a specific person with his presence area or facility against hostilities or against one's own troops or holds them hostage, shall be subject to the penalty of imprisonment from 5 to 25 years.
# Art. 124.
# § 1. Whoever, violating international law, forces the persons mentioned in Art. 123 § 1 to serve in enemy armed forces or to participate in military operations against one's own country, uses corporal punishment, uses violence, illegal threats or deceit to cause these persons to have sexual intercourse, submit to other sexual acts or to perform such acts, is guilty of attack on personal dignity, in particular degrading and humiliating treatment, deprives them of liberty, deprives them of the right to an independent and impartial court or limits the right of these persons to defend themselves in criminal proceedings, declares the rights or claims of citizens of the opposing party as expired, suspended or inadmissible to be brought before a court , is punishable by imprisonment from 3 to 20 years.
# Art. 124.
# § 2. The same penalty shall be imposed on anyone who, in violation of international law, delays the repatriation of prisoners of war or civilians, relocates, resettles or deports the civilian population, conscripts or recruits persons under 18 years of age into the armed forces or actually uses such persons in hostilities. .
# Art. 125.
# § 1. Whoever, in an occupied or occupied area or in which hostilities are taking place, in violation of international law, destroys, damages, takes away or appropriates property or cultural property, shall be subject to the penalty of imprisonment from one to 10 years.
# Art. 125.
# § 2. If the act concerns property of significant value or property of particular importance for culture, the perpetrator shall be subject to the penalty of imprisonment from 3 to 20 years.
# Art. 126.
# § 1. Whoever uses the symbol of the Red Cross or Red Crescent contrary to international law during hostilities shall be subject to the penalty of imprisonment for up to 3 years.
# Art. 126.
# § 2. The same punishment shall be imposed on anyone who, in the course of warfare, uses, in violation of international law, a protective emblem for cultural property or another emblem protected by international law or uses a national flag or the military insignia of the enemy, a neutral state or an international organization or commission.
# Art. 126a.
# Ktopublicznienawołujedopopełnieniaczynuokreślonegowart.118,118a,119§ 1,art.120–125 lubpubliczniepochwalapopełnienieczynuokreślonegowtychprzepisach,podlegakarzepozbawieniawolnościod3miesięcydolat5.
# Art. 126b.
# § 1. Whoever, failing to fulfill the obligation of proper control, allows the commission of the act specified in Art. 117 § 3, art. 118, 118a, 119 § 1, art. 120-126a by a person under his actual power or control, shall be subject to the penalty specified in these provisions.
# Art. 126b.
# § 2. If the perpetrator acts unintentionally, he or she shall be subject to the penalty of imprisonment from 3 months to 5 years.
# Art. 126c.
# § 1. Whoever makes preparations for the crime specified in Art. 117, art. 118 or art. 120, shall be punishable by imprisonment from 3 to 20 years.
# Art. 126c.
# 2. Whoever makes preparations for the crime specified in Art. 118a § 1 or
# Art. 126c.
# § 2, art. 122 or art. 123, is punishable by imprisonment from one to 10 years.
# Art. 126c.
# § 3. Whoever makes preparations for the crime specified in Art. 124 § 1 or art. 125, is punishable by imprisonment for up to 3 years.

# %%
patterns = ['from {digits} months to {digits} years',
'for years {digits} to {digits}',
'from {digits} to {digits} years',
'of {digits} to {digits} years',
'for up to {digits} months. months to {digits} years',
'up to {digits} years',
'from one to {digits} years',
'between {digits} and {digits} years',
'between {digits} months and {digits} years',
'between one and {digits} years',
'not less than {digits} years',]

for i in range(len(patterns)):
  print(patterns[i])
  print('\n')
# Out:
# from {digits} months to {digits} years
#
#
# for years {digits} to {digits}
#
#
# from {digits} to {digits} years
#
#
# of {digits} to {digits} years
#
#
# for up to {digits} months. months to {digits} years
#
#
# up to {digits} years
#
#
# from one to {digits} years
#
#
# between {digits} and {digits} years
#
#
# between {digits} months and {digits} years
#
#
# between one and {digits} years
#
#
# not less than {digits} years

# %% [markdown]
# **Exercise 10.**
#
# We are interested just in upper limits. Compare the patterns from previous exercise and explain why the below algorithm uses just four and it is enough. Make a discussion about that.

# %%
# Assign examples to variable 'paragraph' and run the code to see result.

paragraph = '§ 3. Whoever publicly calls for the initiation of a war of aggression or publicly approves the initiation or conduct of such a war shall be subject to the penalty of imprisonment from 3 months to 5 years.'

# The first pattern.
if re.findall('to \d+ ', paragraph) != []:
  penalty = re.findall('\d+', re.findall('to \d+ ', paragraph)[-1])[-1] # this line extract number from paragraph, the pattern you are looking for is in previous line
# The second pattern.
elif re.findall('and \d+ ', paragraph) != []:
  penalty = re.findall('\d+', re.findall('and \d+ ', paragraph)[-1])[-1] # this line extract number from paragraph, the pattern you are looking for is in previous line
# The third pattern.
elif re.findall('not less than \d+ ', paragraph) != []:
# Why is the value here 30? HINT: look again at previous exercise
  penalty = 30
else:
  penalty = np.nan

# The fourh pattern.
if re.findall('up to one year', paragraph) != []:
  penalty = 1


print(penalty)

## HINT: the patterns are the first argument of the function findall() from the module re
# Out:
# 5

# %% [markdown]
# **Exercise 11.**
#
# Use our pre-defined function from our SICSS module to change dictionary of criminal code to Pandas' data frame.

# %%
# Convert cc_special to pandas' DataFrame using the function dict2DataFrame(dict) from our SICSS module.

cc_df = sicss.dict2DataFrame(cc_special)

## HINT: this is analogical to the exercise 2.
# Out:
# 100%|██████████| 22/22 [00:01<00:00, 19.89it/s]

# %% [markdown]
# **Exercise 12.**
#
# Ask ChatGPT about assumptions of ANOVA test and how you can check them in Python. (To do so use a functions from scipy module). Ask ChatGPT what to do when assumptions are not met. Make a discussion about that.

# %% [markdown]
# **Exercise 13.**
#
# Fulfill below code with proper function to check if data are normally distributed. Why do we need a loop? Are data normally dustributted?

# %%
# Replace '____' with proper function.
# What does the output mean?

for i in cc_df['chapter'].unique():
  print(shapiro(cc_df[cc_df['chapter'] == i]['penalty'].dropna()).pvalue)

## HINT: you should use the Shapiro-Wilk's test here.
## HINT2: are the p values below 0.05?
# Out:
# 0.027455879375338554
# 0.00039109535282477736
# 0.011587492190301418
# 1.8246011677547358e-05
# 0.022254066541790962
# 0.0054634977132081985
# 0.024093644693493843
# 0.01399766094982624
# 1.0
# 0.0006942665786482394
# 0.036846742033958435
# 1.0
# 0.16700315475463867
# 0.001961898058652878
# 0.0007022767676971853
# 0.02881479635834694
# 0.0003469569783192128
# 0.11494914442300797
# 9.02479951037094e-05
# 0.0002265824150526896
# 4.987105626241828e-07
# 0.0014723255299031734
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "

# %% [markdown]
# **Exercise 14.**
#
# Run codes below. Which one is correct and why the results are different? Make a discussion about that.

# %%
groups = cc_df['chapter'].unique()

# ANOVA test
results_anova = f_oneway(
    cc_df[cc_df['chapter'] == groups[0]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[1]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[2]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[3]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[4]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[5]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[6]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[7]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[8]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[9]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[10]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[11]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[12]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[13]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[14]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[15]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[16]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[17]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[18]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[19]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[20]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[21]]['penalty'].dropna()
)

# Kruskal-Wallis test
results_kruskal = kruskal(
    cc_df[cc_df['chapter'] == groups[0]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[1]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[2]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[3]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[4]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[5]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[6]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[7]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[8]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[9]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[10]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[11]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[12]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[13]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[14]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[15]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[16]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[17]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[18]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[19]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[20]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[21]]['penalty'].dropna()
)

## HINT: were the assumptions met?

# %%
# Results of ANOVA test
# How to read the output?
# What does the output mean?

print(results_anova)
# Out:
# F_onewayResult(statistic=4.493953503583276, pvalue=7.397148488705208e-10)

# %%
# Results of Kruskal-Wallis test
# How to read the output?
# What does the output mean?

print(results_kruskal)
# Out:
# KruskalResult(statistic=71.03005514823246, pvalue=2.4003255597420945e-07)

# %% [markdown]
# **Exercise 15.**
#
# Perform post hoc test using codes below. Compare the results and explain which one is correct. Make a discussion about that.

# %%
# HSD Tukey's test
results_tukey_hsd = tukey_hsd(
    cc_df[cc_df['chapter'] == groups[0]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[1]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[2]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[3]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[4]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[5]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[6]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[7]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[8]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[9]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[10]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[11]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[12]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[13]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[14]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[15]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[16]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[17]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[18]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[19]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[20]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[21]]['penalty'].dropna()
)

# Dunn's test
results_dunn = sp.posthoc_dunn(
    [cc_df[cc_df['chapter'] == groups[0]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[1]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[2]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[3]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[4]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[5]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[6]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[7]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[8]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[9]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[10]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[11]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[12]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[13]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[14]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[15]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[16]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[17]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[18]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[19]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[20]]['penalty'].dropna(),
    cc_df[cc_df['chapter'] == groups[21]]['penalty'].dropna()]
)

## HINT: are the specific post hoc tests paired to ANOVA or Kruskal-Wallis test?

# %%
# Results of ANOVA test
# How to read the output?
# What does the output mean?

print(results_tukey_hsd)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)      1.194     1.000    -6.327     8.716
#  (0 - 2)     11.373     0.001     2.777    19.969
#  (0 - 3)      7.327     0.030     0.296    14.358
#  (0 - 4)      6.844     0.184    -0.992    14.681
#  (0 - 5)      9.578     0.009     1.145    18.011
#  (0 - 6)      9.333     0.006     1.293    17.374
#  (0 - 7)      7.978     0.091    -0.455    16.411
#  (0 - 8)     14.444     0.078    -0.598    29.487
#  (0 - 9)      6.618     0.187    -0.972    14.209
#  (0 - 10)     10.194     0.009     1.205    19.184
#  (0 - 11)     15.444     0.036     0.402    30.487
#  (0 - 12)     14.444     0.001     3.074    25.815
#  (0 - 13)      9.122     0.001     1.974    16.270
#  (0 - 14)     11.792     0.000     4.201    19.383
#  (0 - 15)     12.778     0.010     1.407    24.149
#  (0 - 16)      9.204     0.002     1.748    16.661
#  (0 - 17)     12.291     0.000     3.511    21.070
#  (0 - 18)      9.556     0.004     1.515    17.596
#  (0 - 19)      9.444     0.001     2.207    16.682
#  (0 - 20)     10.596     0.000     3.528    17.664
#  (0 - 21)     10.069     0.061    -0.180    20.319
#  (1 - 0)     -1.194     1.000    -8.716     6.327
#  (1 - 2)     10.179     0.002     2.067    18.290
#  (1 - 3)      6.132     0.084    -0.298    12.563
#  (1 - 4)      5.650     0.401    -1.653    12.953
#  (1 - 5)      8.383     0.025     0.444    16.323
#  (1 - 6)      8.139     0.018     0.618    15.660
#  (1 - 7)      6.783     0.218    -1.156    14.723
#  (1 - 8)     13.250     0.148    -1.521    28.021
#  (1 - 9)      5.424     0.409    -1.615    12.462
#  (1 - 10)      9.000     0.026     0.472    17.528
#  (20 - 3)     -3.269     0.923    -9.164     2.625
#  (20 - 4)     -3.752     0.930   -10.587     3.084
#  (20 - 5)     -1.018     1.000    -8.530     6.493
#  (20 - 6)     -1.263     1.000    -8.331     5.805
#  (20 - 7)     -2.618     1.000   -10.130     4.893
#  (20 - 8)      3.848     1.000   -10.697    18.394
#  (20 - 9)     -3.978     0.838   -10.530     2.574
#  (20 - 10)     -0.402     1.000    -8.533     7.730
#  (20 - 11)      4.848     1.000    -9.697    19.394
#  (20 - 12)      3.848     1.000    -6.857    14.554
#  (20 - 13)     -1.474     1.000    -7.507     4.559
#  (20 - 14)      1.196     1.000    -5.356     7.748
#  (20 - 15)      2.182     1.000    -8.523    12.887
#  (20 - 16)     -1.392     1.000    -7.787     5.004
#  (20 - 17)      1.695     1.000    -6.204     9.593
#  (20 - 18)     -1.040     1.000    -8.108     6.027
#  (20 - 19)     -1.152     1.000    -7.291     4.988
#  (20 - 21)     -0.527     1.000   -10.032     8.979
#  (21 - 0)    -10.069     0.061   -20.319     0.180
#  (21 - 1)     -8.875     0.142   -18.722     0.972
#  (21 - 2)      1.304     1.000    -9.387    11.994
#  (21 - 3)     -2.743     1.000   -12.221     6.736
#  (21 - 4)     -3.225     1.000   -13.316     6.866
#  (21 - 5)     -0.492     1.000   -11.052    10.069
#  (21 - 6)     -0.736     1.000   -10.986     9.513
#  (21 - 7)     -2.092     1.000   -12.652     8.469
#  (21 - 8)      4.375     1.000   -11.955    20.705
#  (21 - 9)     -3.451     1.000   -13.352     6.450
#  (21 - 10)      0.125     1.000   -10.885    11.135
#  (21 - 11)      5.375     1.000   -10.955    21.705
#  (21 - 12)      4.375     1.000    -8.652    17.402
#  (21 - 13)     -0.948     1.000   -10.513     8.618
#  (21 - 14)      1.723     1.000    -8.178    11.624
#  (21 - 15)      2.708     1.000   -10.319    15.735
#  (21 - 16)     -0.865     1.000   -10.663     8.933
#  (21 - 17)      2.221     1.000    -8.618    13.060
#  (21 - 18)     -0.514     1.000   -10.763     9.736
#  (21 - 19)     -0.625     1.000   -10.258     9.008
#  (21 - 20)      0.527     1.000    -8.979    10.032

# %%
# Results of Kruskal-Wallis test
# How to read the output?
# What does the output mean?

print(results_dunn)
# Out:
#           1         2         3         4         5         6         7   \
# 1   1.000000  0.456560  0.000374  0.016231  0.158648  0.012093  0.011873
# 2   0.456560  1.000000  0.002074  0.078867  0.455724  0.049983  0.051765
# 3   0.000374  0.002074  1.000000  0.074119  0.020134  0.293378  0.228494
# 4   0.016231  0.078867  0.074119  1.000000  0.389160  0.568754  0.635954
# 5   0.158648  0.455724  0.020134  0.389160  1.000000  0.219585  0.241349
# 6   0.012093  0.049983  0.293378  0.568754  0.219585  1.000000  0.911938
# 7   0.011873  0.051765  0.228494  0.635954  0.241349  0.911938  1.000000
# 8   0.026633  0.099072  0.184852  0.810385  0.353305  0.779405  0.855619
# 9   0.000407  0.001276  0.140795  0.012511  0.004782  0.035820  0.028471
# 10  0.059239  0.215386  0.046739  0.691862  0.657234  0.392736  0.436289
# 4   0.279254  0.031968  0.101105  0.240290  0.101483  0.109346
# 5   0.078558  0.008186  0.026562  0.063439  0.023293  0.037151
# 6   0.739918  0.167725  0.388839  0.705529  0.472819  0.301304
# 7   0.634210  0.122961  0.307834  0.596558  0.370845  0.247696
# 8   0.518852  0.099055  0.248388  0.484271  0.295404  0.205064
# 9   0.046022  0.208970  0.099838  0.046513  0.067148  0.196212
# 10  0.174789  0.020125  0.063078  0.148098  0.061864  0.072889
# 11  0.805736  0.412634  0.775106  0.827923  0.931992  0.572292
# 12  0.010283  0.071691  0.027449  0.010289  0.015987  0.070647
# 13  0.010860  0.131894  0.040628  0.010599  0.018790  0.131824
# 14  0.823464  0.151162  0.393586  0.781285  0.483880  0.308222
# 15  0.330135  0.701564  0.778478  0.334245  0.540546  0.878516
# 16  0.252826  0.830720  0.487882  0.257269  0.361822  0.744873
# 17  1.000000  0.225618  0.532730  0.965634  0.664120  0.396920
# 18  0.225618  1.000000  0.542829  0.227764  0.360863  0.875805
# 19  0.532730  0.542829  1.000000  0.546185  0.790856  0.721852
# 20  0.965634  0.227764  0.546185  1.000000  0.684634  0.405286
# 21  0.664120  0.360863  0.790856  0.684634  1.000000  0.561226
# 22  0.396920  0.875805  0.721852  0.405286  0.561226  1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# **Exercise 16.**
#
# Perform analysis to check the hypothesis that the chapters in polish criminal code are ordered by severity in terms of fine. You can use the code below as template.
#
# HINT: You should collaborate and discuss during this exercise.

# %%
# Plot presenting data mean penalty vs. number of chapter
cc_df.groupby('num_chapter').agg(mean_penalty = ('penalty', 'mean')).plot()
plt.show()

# How to read the plot?

# %%
# Plot presenting data actual number of chapter vs. expected number of chapter
ar_df = cc_df.groupby('num_chapter').agg(mean_penalty = ('penalty', 'mean')).sort_values('mean_penalty',
                                                                                         ascending = False)
ar_df['index'] = np.arange(0, len(ar_df)) + 16
ploting_data = ar_df.reset_index().sort_values('num_chapter')
plt.scatter(ploting_data['num_chapter'], ploting_data['index'])
plt.plot(ploting_data['num_chapter'], ploting_data['num_chapter'], color = 'orange')
plt.show()

# What does it mean that point lays on the line?

# %%
# Obtain p_value
test_statistic = 3
sicss.p_value_of_testing_order(test_statistic, 22)

# What does the output mean?
# Out:
# 0.0004277229309082031

# %%
# Warm-up questions!
# Let us assume that you have column that indicates gender, 1 means female, 0 means male.
# Can you calculate a mean of this columns? If so, what it would mean?
# How it is connected to to fine column in our dataset?

# %%
# Enter your code here
cc_df.groupby('num_chapter').agg(mean_penalty = ('fine', 'mean')).plot()
plt.show()

# %%
# Plot presenting data actual number of chapter vs. expected number of chapter
ar_df = cc_df.groupby('num_chapter').agg(mean_fine = ('fine', 'mean')).sort_values('mean_fine',
                                                                                         ascending = True)
ar_df['index'] = np.arange(0, len(ar_df)) + 16
ploting_data = ar_df.reset_index().sort_values('num_chapter')
plt.scatter(ploting_data['num_chapter'], ploting_data['index'])
plt.plot(ploting_data['num_chapter'], ploting_data['num_chapter'], color = 'orange')
plt.show()

# %%
test_statistic = 2
sicss.p_value_of_testing_order(test_statistic, 22)
# Out:
# 6.0558319091796875e-05
